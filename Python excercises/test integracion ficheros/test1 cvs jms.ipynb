# %%
# Abre y lee el fichero
import csv
datafile = open("PitchingPost.csv")
content = csv.reader(datafile)
anyoAnt = 0
contAnual = 0
for linea in content:
    if content.line_num == 1: 
        continue # Saltar primera linea ya que son los encabezados
    lista = list(linea) #convertir cada línea en lista
    anyo = lista[1]
    if (content.line_num == 2):  # Solo para la primera línea de datos
        anyoAnt = anyo
    if (anyoAnt == anyo):
        contAnual += 1
    else:
        print (anyo, contAnual)
        anyoAnt = anyo
        contAnual = 1
datafile.close()


# calcula la cantidad de registros por cada año
    
# escribe el resultado     
#result = open('promedios.csv', 'w')
#result = csv.writer(resut,delimiter=',',lineterminator='\n')
#result.whiterow()
#result.close
# Out:
# 1885 3
# 1886 4
# 1887 7
# 1888 6
# 1889 9
# 1890 9
# 1892 6
# 1903 6
# 1905 8
# 1906 6
# 1907 8
# 1908 8
# 1909 9
# 1910 11
# 1911 9
# 1912 8
# 1913 10
# 1914 8
# 1915 9
# 1916 7
# 1917 12
# 1918 11
# 1919 8
# 1920 13
# 1921 12
# 1922 12
# 1923 10
# 1924 13
# 1925 17
# 1926 13
# 1927 15
# 1928 11
# 1929 9
# 1930 12
# 1931 12
# 1932 12
# 1933 14
# 1934 12
# 1935 14
# 1936 12
# 1937 14
# 1938 14
# 1939 12
# 1940 12
# 1941 17
# 1942 14
# 1943 13
# 1944 11
# 1945 15
# 1946 17
# 1947 18
# 1948 17
# 1949 14
# 1950 14
# 1951 10
# 1952 17
# 1953 14
# 1954 19
# 1955 13
# 1956 19
# 1957 16
# 1958 17
# 1959 15
# 1960 16
# 1961 20
# 1962 15
# 1963 13
# 1964 11
# 1965 17
# 1966 16
# 1967 12
# 1968 20
# 1969 19
# 1970 44
# 1971 43
# 1972 47
# 1973 50
# 1974 43
# 1975 38
# 1976 48
# 1977 42
# 1978 46
# 1979 48
# 1980 49
# 1981 44
# 1982 108
# 1983 45
# 1984 43
# 1985 46
# 1986 48
# 1987 48
# 1988 53
# 1989 50
# 1990 50
# 1991 50
# 1992 57
# 1993 58
# 1995 57
# 1996 129
# 1997 130
# 1998 124
# ...
